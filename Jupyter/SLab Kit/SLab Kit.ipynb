# %% [markdown]
# <img style="float: right;"  src="images/LogoP.jpg" width="200">
#
# # SLab Kit
#
# This document describes the **SLab Kit** provided in the ETSETB to support the learning of electronics.
#
# Version 1.0 (12/4/2019)
# License information is at the end of the document

# %% [markdown]
# ## Introduction
#
# The **Small Lab** (SLab) project pretends to ease self learning in electronics. The objective of the project is to learn by working on lab measurements. That is, by building and measuring circuits.
# Practical work is quite normal in most engineering subjects. This work is usually performed in the laboratories of the schoool.
# The objective of the **SLab** system is to move the practical work out of the laboratories by providing a cheap small but powerful measurement system that can be used anywhere.
# The **SLab** system requires a **Hardware Board**, some jumper wires, a solderless breadboard and components to build circuits. There are multiple options to build a system.
#
# As an example the **Fat Board** adds some standard banana, BNC and Jack connectors to the basic SLab system..
#
# ![Fat Board](images/fat_board.jpg)
#
# In a more compact size, the **Long Board** fit all the basic SLab elements to a base plate so that they are mechanically joined together.
#
# ![Long Board](images/long_board.jpg)
#
# The most minimalistic version of the system is the **Minimal SLab System**. It just includes a hardware board, a bread board and the jumper wires without any mechanical support. By being minimalistic, the system can be obtained without the added time and cost associated to mechanical actions. The system, when working, should resemble someting like the following image.
#
# ![Slab Kit](images/system.jpg)
#
# The **SLab Kit** that relates to this document can include the **Long Board** or just the **Minimal SLab System**. It can be provided in three possible kit options:
#
# **SLab Minikit**
# Just contains a Hardware board, an USB cable, 10 jumper wires, and a box of components.
#
# **SLab Kit**
# Adds a carrying case and a solderless breadboard to the SLab Minikit.
#
# **Longboard Kit**
# Similar to the SLab Kit, but a Longboard is provided instead of just the Minimal SLab System.
#
# Each one of the above kits can contain some additional optional elements.

# %% [markdown]
# ## What is in the Kit
#
# The kit is divided in two main sets of components: **The SLab System** and an **Electronics Components Set**
#
# The **SLab System** is, at least, composed of:
#
# * An [STM32F303RE Nucleo64](https://www.st.com/en/evaluation-tools/nucleo-f303re.html) demonstration board that operates as the **SLab Hardware Board**
# * An **USB Mini** cable to connect the board to the computer
# * 10 Female to Male Jumper Wires to connect the **Hardware Board** with the **Breadboard**
#
# The **SLab Kit** and the **Longboard Kids** add to the above:
#
# * A carying case
# * A Solderless **Breadboard** to build the circuits
#
# As explained, the **Nucleo Board** and the **Breadboard** can be provided combined on a **Long Board** setup or they can be separated from each other as in the **Minimal SLab System**.
#
# If the kit contains a **breadboard**, a red LED diode and a resistor are permanently included to always know if it is powered. If you are the first user of the kit, those components could not be already mounted on the breadboard.
#
# If the kit does not include a **breadboard** you will need to provide one yourself as this is a required element to work with the **SLab system**.
#
# The following image shows the inside of a **SLab Kit** case that includes most of the optional components in this kit.
#
# ![Components](images/SLab_Kit_Inside.jpg)
#
# The **Electronics Components Set** is a set of electronic components that is enough for all the proposed **SLab** experiments. It curretly includes:
#
# * A box to put inside all the components
# * 12 capacitors: $1nF$, $10nF$, $100nF$, $1\mu F$, $10 \mu F$ and $100 \mu F$ (2 of each value)
# * 2x $10 k\Omega$ trimpots
# * 2x MCP6002 Dual Opamp DIP8 Integrated Circuits
# * 2x BC547B NPN BJT transistors
# * 2x BC557B PNP BJT transistors
# * A BS170 NMOS transistor
# * A TP2104 PMOS transistor
# * 4x 1N4148 silicon diodes
# * 4x BAT42 Schottky diodes
# * 4x LED diodes: 2 red, 1 Green, 1 Blue
# * Some pieces of unifilar electric wire with different colors
#
# The **datasheets** of most of those components can be found on the [SLab Kit Datasheets Folder](/tree/SLab%20Kit/Datasheets)
#
# The following figure shows the **Electronics components box** before adding resistors to the first fow.
#
# ![Components](images/Component_Box.jpg)
#
# The above image contains an optional **Supply supervisor** component in the center bottom row. This component is not need in most kits and is only provided, as an option, in the **SLab Minikit**.

# %% [markdown]
# ## Optional Kit Elements
#
# In addition to the above elements, any SLab Kit could also contain:
#
# * Two **resistor sets**
# * Some single core wire pieces of different colors
# * A **SLab Pendrive** with the software preinstalled
# * A **pin locating card** for the Hardware board
# * A **Supply supervisor** that can only be provided in the **SLab Minikit**
#
# If the kit does not provide **resistors**, you will need to provide the needed resistors for each **SLab tutorial**. Also, if the kit does not provide some single core wires, you will need to provide it to perform the connection on the **breadboard**.
#
# Both the **Pin Locating card** the **SLab Pendrive** and the **Supply supervisor** are completelly optional. You can work just fine without them.
#
# The **Pin locating card** assist the connection of the jumper wires on the **Hardware board**.
#
# The **SLab Pendrive** provides a plug and play standalone software solution for Windows systems.
#
# The **Supply supervisor** provides a LED to check the board power when using an user provided breadboard. As only the **SLab Minikit** lacks a **breadboard**, it can only be provided with this kit.

# %% [markdown]
# ## What is not in the Kit
#
# The **SLab Kit** includes most of the items to work on the proposed experiments. It does not include, however, some needed elements:
#
# **A PC Computer**
# In order to operate the **SLab System** you need a PC computer. The **SLab Kit** is plug and play in a **64 bit Windows** operating system, but it can also operate, if you install the needed **Python** software, on **Linux** or **Mac** computers.
#
# **Tools for stripping and cutting wires**
# Some unifilar wire is provided but you will need to cut it and strip the plastic isolation at its ends. Any cutting plier will do. You could also use scissors but, unless they are designed for cutting copper, you will probably damage them.
#
# **A Multimeter**
# During the calibration of the **Hardware board** you will need a [Multimeter](https://en.wikipedia.org/wiki/Multimeter). This instrument is not needed for normal **SLab** operation, so you only need to have access to this instrument once if the board has not been callibrated.

# %% [markdown]
# ## About the Hardware Board
#
# The **Hardware Board** is the board that interfaces both with the host PC and the circuit we want to measure. This board need to have, at least, one USB connector with a **serial over USB** link for communication with the host PC, two [DAC](https://en.wikipedia.org/wiki/Digital-to-analog_converter) outputs and four [ADC](https://en.wikipedia.org/wiki/Analog-to-digital_converter) inputs.
#
# Any boad that satify the previous requirements can be used as a **SLab Hardware Board** as long as it includes the needed **Firmware** to communicate with the PC. Although there are plans to suppor other boards, currently the best supported board is the [STM32F303RE Nucleo64 board](https://www.st.com/en/evaluation-tools/nucleo-f303re.html). This is the board provided as part of the **SLab Kit**. You can see an image of the board below.
#
# ![Board Elements](images/board_elements.jpg)
#
# Now we will describe the most important elements on the board, respect to the SLab usage. If at some point you don't understand the explanations, don't worry, you don't need to know all about the board internals to use it. First thing is the connection to the **host PC**:
#
# * A **mini USB** connector, inside the pale blue box on the image, to connect to the host PC.
#
# The board features **LEDs**, shown iside the three red boxes:
#
# * A communication bicolor red/green **LD1** LED on the top right.
#
# * An user green **LD2** LED on the center right.
#
# * A power red **LD3** LED on the center left.
#
# The communication **LD1** LED is a bicolor led that indicates the state of the debug link with the host PC. In normal operation it will light in **red** color. During the firmware upload operation it will link. It will only shine in solid **green** color after uploading a new firmware and until the next power-up.
#
# The **LD2** LED is the user LED. Unfortunatelly the user LED is connected to the same microcontroller line of the **second DAC** output. That limits the **DAC** performance. From an user point of view, if you see light on this LED, that means that the **DAC2** output quatlity is starting to degrade. There is a documented method to remove this LED connection and access the full performance of **DAC2** but it requires some SMD desoldering.
#
# When you receive the **SLab Kit** it is possible for the board to come with a yellow sticker that contains a number or a number followed by an **"X"** letter. If your board contains this sticker and it includes the **"X"** letter, it means that the **DAC2** has been disconnected from the **LD2** LED as described in [this document](http://localhost:8888/notebooks/Boards/Nucleo_F303RE_Zero/Board%2003%20-%20DAC2%20Improvement.ipynb). This means that **DAC2** will have improved operation but it also means that the user **LD2** cannot be used.
#
# The red **LD3** LED is the power LED. In indicates when the main CPU is powered. It should lit whenever the board is connected to a host PC. The board supports power negotiation with the PC. If the PC is not able to provide the power the board needs, this LED will turn off and the **SLab System** will be non operational.
# It is interesting to note that the power **LD3** LED is connected to the internal $5V$ board supply rail that comes from the USB cable. This supply goes through a $3.3V$ LD39050 regulator before reaching the main MCU power rails. If you shortcircuit the breadboard power rails, no harm will be made to the board or the USB connection and, in fact, the **LD3** will continue to light-up as the $5V$ rail is unaffected when the $3.3V$ rail is shorted.
#
# There are two big two column male **ST morpho** connectors, shown inside the yellow rectangles, on the sides of the board:
#
# * Connector **CN7** on the left side
#
# * Connector **CN10** on the right side
#
# Those connectors give access to all the MCU pins and are used to interface with the circuit we will measure.
#
# There are two buttons in the board, shown inside the green rectangles:
#
# * Blue **User** button that implements the **Halt** function
#
# * Black **Reset** button to rese the board
#
# The user button implements the firmware **Halt** function, when you press this button the firmware stopts watever it is doing, returns an error code, and waits for new commands. This function is interesting if you, by mistake, send a too long to complete command to the board.
#
# The **reset** button gives access to the main MCU reset line. If you press this button the MCU will reset and you will need to reconnect to the board. This button is useffull if the board hangs-up and is not recoverable by the **Halt** function.
#
# To end this board description we have three jumper locations on the board, shown inside the orange boxes in the image. From top to bottom of the board:
#
# * **CN2** ST-Link pair of jumpers
#
# * **JP5** power selection jumper
#
# * **JP6** $I_{DD}$ measurement jumper
#
# Jumpers are important because they are detachable from the board and, if you miss them, the board won't operate as intended.
#
# The two top jumpers at **CN2** connect the main MCU debug port with the USB connector. You don't need those jumpers for normal operation of the board, but, if you remove them, you won't be able to upload any new firmware on the board.
#
# The **JP5** jumper is a two position jumper that selects how the main MCU is powered. In order to power the MCU using the USB connector, it shall be on the right *U5V* position. If you put it on the left *E5V* position, you will need to power the MCU using the **E5V** pin at the **CN7** connector. If you take out the jimpler, the MCU won't be powered at all.
#
# The final **JP6** jumper connects the $3.3V$ rail with the main MCU $V_{DD}$ input. This jumper is meant to be substituted by an amperimeter to measure the current consumed by the MCU. You should never take off this jumper as it will remove the MCU power input.

# %% [markdown]
# ## Board Power
#
# This section provides some more details about the board power management. This section is not crytical so, if you don't want to know about this subject, you can skip it.
#
# The following image shows the schematic of the board power management.
#
# ![Power Schematic](images/power_sch.png)
#
# If you are curious, you can also read the rest of the board [schematics](http://localhost:8888/files/Boards/Nucleo_F303RE_Zero/PDF/STM32F303RE%20Nucleo%20Schematics.pdf).
#
# Some of the nodes have special meanings:
#
# * **U5V** is the $5V$ rail obtained from the PC USB connection
# * **VIN** is a pin available on **CN7** that enables powering the MCU from an external unregulated supply
# * **E5V** is a pin available on **CN8** that enables powering the MCU from an external regulated $5V$ supply
# * **+5V** is the the power rail, **E5V** or **U5V**, selected by **JP5** to power the main MCU
# * **+3V3** is the $3.3V$ rail before the **JP6** current measurement jumper
# * **VDD** is the $3.3V$ rail after the **JP6** current measurement jumper
#
# Note that transistor **T2** connects the **U5V** rail to the **JP5** jumper. This transistor will only turn when the **PWR_ENn** signal is enabled after the power negotiation with the PC succeeds. If your PC is not able to provide the required power, you can use an external power supply. In this case you would put the **JP5** jumper on the left *E5V* position and will use either the **E5V** or the **VIN** pins to power the main MCU. This option has the added benefit that, as the MCU is not powered by the host PC, the PC is somewhat more proteccted against user errors.
# The [Nucleo64 Board Manual](http://localhost:8888/files/Boards/Nucleo_F303RE_Zero/PDF/STRM32%20Nucleo64%20User%20Manual.pdf) in the **Power supply and power selection** section gives a more in depth explanation about those options.
#
# As you can see in the schematic the MCU **VDD** $3.3V$ rail is provided by the **U4** regulator. That isolates somewhat the MCU supply from the USB power rail. That offers some protection if, for instance, you short the the $V_{DD}$ rails on the breadboard when doing some experiments.
#
# See also that the red **LD3** LED is connected to the $5V$ rail so, as explained before, having it lit does not mean that the $3V3$ rail is available.

# %% [markdown]
# ## Board Documentation
#
# The **STM32F303RE Nucleo64** board is a quite capable board. Kudos to ST for providing such a small, powerfull, versatile and well documented board.
#
# In the folder:
#
# $\qquad$ `SLab/Jupyter/Boards/Nucleo_F303RE_Zero/PDF`
#
# there are some documents about this board, or some of its main elements:
#
# * Nucleo64 board [User Manual](http://localhost:8888/files/Boards/Nucleo_F303RE_Zero/PDF/STRM32%20Nucleo64%20User%20Manual.pdf)
#
# * Board [Schematic](http://localhost:8888/files/Boards/Nucleo_F303RE_Zero/PDF/STM32F303RE%20Nucleo%20Schematics.pdf)
#
# * Main **STM32F303RE** MCU [datasheet](http://localhost:8888/files/Boards/Nucleo_F303RE_Zero/PDF/STM32F303%20Datasheet.pdf)
#
# * STM32F303 **mixed signal family** MCU [reference](http://localhost:8888/files/Boards/Nucleo_F303RE_Zero/PDF/STM32F303%20Reference.pdf)
#
# All those documents are property of [ST](https://www.st.com/content/st_com/en.html) and are the main documents used to develop the board **firmware**.
# You can obtain more up to date documentation about the **STM32F303RE Nucleo64** board in its [web page](https://www.st.com/en/evaluation-tools/nucleo-f303re.html).
#
# The current firmware for this board has been developed using the [ChibiOS/RT](http://www.chibios.org/dokuwiki/doku.php) operating system in a custom [Eclipse](https://www.eclipse.org/) setup.
# Code compilation uses the [GNU-ARM compiler toolchain](https://developer.arm.com/tools-and-software/open-source-software/gnu-toolchain/gnu-rm).
#
# The board is compatible with the [MBED](https://www.mbed.com/en/) system. Board details for **MBED** operation can be found on this [link](https://os.mbed.com/platforms/ST-Nucleo-F303RE/). In fact, the first versions of the **SLab** firmware were developed on **MBED**.
#
# ![MBED](images/mbed_small.png)
#
# If at some point of time you are bored of **SLab**, you can use the **MBED Cloud Compliler** to learn about **firmware programming** using the same Nucleo64 board. If, at some time, you want to return to **SLab**, you just need to reupload the **SLab firmware**.

# %% [markdown]
# ## Kit One-Time actions
#
# There are some actions that need to be done on the kit only one time. If you are the first user of the kit, you will need to do those actions. If your kit has been previously used by someone, those actions have already been made for you so you could skip this section although it is a good idea to read it to check that everything is as it should.
#
# If your **Kit** is in the **Minimal SLab System** category, is is possible that the board is provided in the blister box from the manufacturer. The first thing to do is to fit the three plastic spacers, if they are not fitted yet, so that the board connectors in the bottom side don't touch the table when you use the board.
# Three screws and three spacers are provided. The screw locations are shown on the next figure. Note that screw **number 3** is different because there is too little clearance to the Arduino **CN5** connector on this holes and a normal screw won't fit.
#
# ![Board Screws](images/screws.jpg)
#
# The next action is to implement a LED circuit in the **breadboard**. We will also connect together the two red $V_{DD}$ power strips of the board and the two blue ground $GND$ strips.
#
# ![LED_Circuit](images/LED_Circuit.png)
#
# The led will light if there is voltage in the breadboard rails. If you are working on a circuit and see the light **turn off**, most probably you are **shorting** the power rails. Disconnect the red wire from the breadboard, check the circuit, and reconnect again to see if the problem has been solved. Note that you cannot use the boad **LD3** LED for that. The **LD3** LED is lit when there is a $5V$ rail available. It does not depend on the $3V3$ rail we are using on the breadboard.
#
# Locate a $470\Omega$ resistor in one of the resistor bags and the square red LED.
# The following figure shows an implementation of this circuit. Note the red wire that connect the two $V_{DD}$ rails and the black wire that connects the two $GND$ rails. In the case of the red LED, the long terminal is the one that needs to be connected to the positive rail. If you connect it wrong, it just won’t lit.
#
# ![BB_LED](images/BB_LED.jpg)
#
# If you are using the **SLab Minikit**, that means that no **breadboard** is provided with the kit. In that case, a **Supply supervisor** could be included with the kit. The supervisor just includes a **LED** and a $470\Omega$ **resistor** in a small module that connects over the $3V3$ and $GND$ pins on the **Hardware board**. This way, you don't need to add a the LED and the resistor on your breadboard. If you have a **SLab Minikit** that does not include a **Supply supervisor**, you should add the LED and the resistor to your own board.
#
# ![Supply Supervisor](images/Supervisor.jpg)
#
# The next thing to do is to upload the board **firmware**. First we connect the **Hardware Board** to the PC using the provided mini USB cable. If this is the first time you connect to the PC, wait until the needed drivers are installed. If all goes as it should, the board should be seen from the PC on three different interfaces:
#
# * An ST-Link Debug interface
# * A mass storage device
# * A serial link
#
# In SLab we will use only the last two ones. The **mass storage** to upload the firmware and the **serial link** for normal **SLab** operations.
#
# After the driver installations you should see the board as a new external disk on the PC, probably with a name like **"NODE_F303RE"**. To install the **SLab** firmware just open the **Slab Kit** folder in the root of the **SLab Pendrive** drag the file **"SLAB-Nucleo64-F303RE-v2.0.bin"** you will see on this folder and drop it in the **"NODE_F303RE"** disk. During the firmware installation you will see the COM **LD1** LED on the board blink. After the firmware installation the LED will turn solid green as shown inside the red square in the next figure. But this will be temporal, on the next power-up this LED will turn red again. So, don't worry about this LED color.
#
# ![Green COM](images/green_com2.jpg)
#
# If all goes ok, you now have a **SLab** enabled **Hardware Board**.
# If you have problems uploading the **firmware** check that the two *ST-LINK* jumpers at the top **CN2** connector, shown in the above figure, are in place.
#
# If there is already a firmware on the board, you don't really need to upload the firmware unless there is a newer version available. Check the firmware version when you connect to the board and update it if there is more recent version available.
#
# The last thing to do is sorting all electrical components. The SLab kit provides the first user a plastic box and a set of components in one or three plastic bags:
#
# * A bag with components (always provided)
# * Two identical bags with a full resistor set (optional)
#
# If the optinal resistor sets are providewd, the first row of 5 spaces of the plastic box will be assigned to them. The optional pack includes two resistor bags with one resistor of each value in each bag. You will will put the resistors in the five spaces according to their value:
#
# * $10\Omega$ to $82\Omega$ (leftmost space)
# * $100\Omega$ to $820\Omega$
# * $1k\Omega$ to $8k2\Omega$ (center space)
# * $10k\Omega$ to $82k\Omega$
# * $100k\Omega$ to $820k\Omega$ (rightmost space)
#
# If the pack includes resistors below $10\Omega$ or above $820k\Omega$, just keep them in their bags because probably won't be used on normal **SLab** experiments.
#
# The resistor values are coded using a [Resistor Color Coding](https://en.wikipedia.org/wiki/Electronic_color_code) so, each space will contain resistors ending with a different color (before the gold tolerance ring).
#
# You could open the two plastic bags and classify all the resistors according to their values, but this could be quite time consuming. An alternative strategy is to locate the resistor in the bag each time you need a new resistor value and, after using it, put in the proper location of the box. That way, you won't clutter the box with non used resistors. In order to be able to put the resistor in the indicated space you will need to bend both of their terminals.
#
# The rest of components go to other box spaces as shown in the list:
#
# * 6 Non polarized capacitors: $1nF$, $10nF$, $100nF$ (2 of each value)
# * 6 Electrolitic capacitors: $1\mu F$, $10 \mu F$ and $100 \mu F$ (2 of each value)
# * 2x $10 k\Omega$ trimpots and 2x MCP5002 Dual Opamp DIP8 Integrated Circuits
# * 6 Transistors: 2x BC547B, 2x BC557B, one BS170 and one TP2104
# * 4x 1N4148 silicon diodes and 4x BAT42 Schottky diodes
# * 2x MCP6002 Dual Operational Amplifiers
# * 3x LED diodes: 1 red, 1 Green, 1 Blue
#
# If you do all that you will occupy 12 of the 15 spaces in the box.
#
# After sorting all components, the plastic box will look like the following figure.
#
# > Image of the components box
#
# If you are not the first user of the kit, perhaps the components are already on the box, so, in this case, no bag of components will be provided.
#
# We will leave one or two of the available spaces to put the small one core wire pieces used to connect the components together in the breadboard.

# %% [markdown]
# ## Checking the Board
#
# At this point, connect the **Hardware Board** to the PC using the provided mini USB wire. This should already been done in the previous section if you are the first user of the kit. If not, connect the board and wait for the drivers to install.
#
# During the USB enumeration, the STM32 Nucleo board requires $300 mA$ of current to the host PC. If the host is able to provide the required power, the targeted microcontroller is powered and a red LED will shine near the center of the board. If this LED does not turn on, your PC is not able to power the board. This should not happen unless you are using a simple hub for the USB connection.
#
# You should have a working **Pyhon** system or you won't be reading this **Jupyter Notebook**. But, anyway, just to be sure, execute the following code cell to check the Python software on the PC side.

# %%
# Check the Python installation

import importlib

def check(package):
    try:
        importlib.import_module(package)
    except:
        print('Package',package,'is not installed (ERROR)')
    else:
        print('Package',package,'is installed (OK)')
        
check('serial')
check('numpy')
check('matplotlib')
check('jupyter')

# %% [markdown]
# If the above code gives **OK** to all four packages: serial, numpy, matplotlib and jupyter, then you are good to go. As the **SLab Kit** provides all the software built-in, you can only have problems if you are using a non Windows64 PC or if there is some corruption in the Pendrive data.
#
# Now we can check the connection with the board itself. Just run the following code cell.

# %%
import slab    # Import the main SLab module

boardFolder = ''                                # Board folder (leave '' if you use only one board)
slab.setFilePrefix('../Files/')                 # Set File Prefix
slab.setCalPrefix('Calibrations/'+boardFolder)  # Set Calibration Prefix         
slab.connect()                                  # Connect to the board

# %% [markdown]
# You should see some text that includes a line:
#
# $\qquad$ **Connected to Nucleo64-F303RE ChibiOS SLab2 v2.0**
#
# Or something like that. If this is the case, continue. If not try to reinstall the board firmware as described in the previous **Kit One-Time actions** section.
#
# Now that we know that the board is working, let's connect the **Hardware Board** to the **Breadboard**

# %% [markdown]
# ## Board Connections
#
# As you will see, the provided **Firmware** enables the use of a **3.3V supply**, two **DACs**, eight **ADCs** and 13 digital I/O **DIO** lines on the **STM32 Nucleo F303RE** board. Most **SLab** experiments don't require as much lines so the **SLab Kit** is only provided with ten connection wires although we normally will use only eight of them. The wires will be connected using the **female** end on the **Hardware Board** and the **male** end on the **Breadboard**. The wires are as follows:
#
# * Ground $GND$ wire (Black)
# * $V_{DD}$ supply $3.3V$ wire (Red)
# * **DAC1** wire (Yellow)
# * **DAC2** wire (Orange)
# * **ADC1** wire (Blue)
# * **ADC2** wire (Green)
# * **ADC3** wire (Violet)
# * **ADC4** wire (Brown)
#
# Store the two spare **white** and **grey** wires as we don't usually require them.
#
# The following figure shows the location of all **SLab Signals** on the **Hardware Board**. The right side shows the connections in the dual row **CN7** male connector at the right side of the board whereas the left side shows the connections in the dual row **CN10** male connector at the left side of the board.
#
# Note that there are many more available connections that the eight we are using.
#
# ![F303_Zero_Pinout](images/F303RE_Pinout.png)
#
# The above image is included, for your reference, in the sheet of paper that is inside the **Components box**.
#
# If you think that the previous image is too complex, the following one only shows the eight needed pins.
#
# ![F303_Zero_Simplified Pinout](images/8connections.png)
#
# The following image shows all eight wires connected on the board.
#
# ![Board Wires](images/board_wires.jpg)
#
# There is an additional [document](http://localhost:8888/notebooks/Boards/Nucleo_F303RE_Zero/Board%2004%20-%20Board%20Pin%20Locator.ipynb) that explains how to put a card over the board so that you can easily locate all **SLab** signals. If you are not the first user of the kit, perhaps there is a card ready to be used on your kit. If not, you can create your own one and add it to the kit.
#
# ![Board with card](images/slab_card_onboard.jpg)
#
# Now, we need to connect male ends of the wires to the breadboard. When we are not measuring any particular circuit we will use the SLab **Standard Docking** configuration for the wires. In this configuration:
#
# * The red wire is connected to one of the breadboard positive red rails
# * The black wire is connected to one of the breadboard negative blue rails
# * The orange **DAC2** and green **ADC2** wires are connected together in one breadboard node
# * The rest of wires: yellow **DAC1**, blue **ADC1**, violet **ADC3** and brown **ADC4** are connected to another breadboard node
#
# Use this **Standard Docking** connections whenever you have the **Slab System** connected to a PC and you are not measuring any circuit. Leaving the wires floating arround is not, in general, a good idea. Any wire you are not using for current measurements shall be in the standard docking position.
#
# ![Standard Docking](images/docking.jpg)
#
# You should see the red LED lit as soon as you connect the black and red wires. If not, perhaps you have connected the LED in the wrong way. If, when working on the circuit this LED **turns off**, most probably you are shorting the power rails. Disconnect the **red** $V_{DD}$ wire, check the circuit connections, and connect the wire again to see if the problem has been solved.
#
# If he breadboard **red** LED is off when it was previously on, and the Nucleo Board power red **LD3** LED is also off, the problem is not in your board but in the Nucleo board **power management**. Unless you have fried somethin on the board, of course.
#
# With wires in the standard docking configuration you can check the board operation by executing the **calibration check** on the code cell below.

# %%
# Check the calibration
slab.checkCalibration(pause=False,na=4,nm=10)

# %% [markdown]
# If you are not the first user of the **SLab Kit** and the board has been previously callibrated, you should see four lines, from **ADC1** to **ADC4** with the same values on both axes.
#
# If you are the first user of the board or the board has not been properly callibrated, you could have some deviations of the lines from equal X and Y values specially at the curve ends. Don't worry, this code is only to check that we can communicate with the board and perform measurements.
#
# If you have reached this point, congratulations, you have a working **SLab System**
#
# You can now go to the [Index](http://localhost:8888/notebooks/Index.ipynb) document and start working with the board on the provided **Jupyter Notebooks**.
#
# Note that the first sections of the **Index** document can repeat some of the operations that you have already made. Also, the full **Slab** documentation also explain the software installation that is not needed when using the **SLab Kit** on a Windows64 PC. In any case, it is a good idea to read the documents so you get the most information about the **SLab System** operation.
#
# After performing all the procedures in this document, in future accesses to the **SLab System**, you can always start on the [Index.ipynb](http://localhost:8888/notebooks/Index.ipynb) file located in the SLab Jupyter **root folder**.

# %% [markdown]
# ## Document license
#
# Copyright  ©  Vicente Jiménez (2019)
# This work is licensed under a Creative Common Attribution-ShareAlike 4.0 International license.
# This license is available at http://creativecommons.org/licenses/by-sa/4.0/
#
# <img  src="images/cc_sa.png" width="200">
